# %%
import pandas as pd

# %%
df = pd.read_csv('500_Cities__Local_Data_for_Better_Health__2019_release.csv')

# %%
df.shape
# Out:
# (810103, 24)

# %%
df.head()
# Out:
#    Year StateAbbr StateDesc CityName GeographicLevel DataSource  \
# 0  2016        IL  Illinois  Chicago    Census Tract      BRFSS
# 1  2016        IL  Illinois  Chicago    Census Tract      BRFSS
# 2  2017        IL  Illinois  Decatur    Census Tract      BRFSS
# 3  2016        IL  Illinois   Joliet    Census Tract      BRFSS
# 4  2017        IL  Illinois    Elgin    Census Tract      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes  1714000-17031612000
# 1       Prevention  1714000-17031660700
# 2  Health Outcomes  1718823-17115001100
# 3  Health Outcomes  1738570-17197881603
# 4  Health Outcomes  1723074-17031804405
#
#                                              Measure Data_Value_Unit  ...  \
# 0        All teeth lost among adults aged >=65 Years               %  ...
# 1  Visits to dentist or dental clinic among adult...               %  ...
# 2        Current asthma among adults aged >=18 Years               %  ...
# ...

# %%
df['MeasureId'].value_counts()
# Out:
# COPD            29006
# DIABETES        29006
# BINGE           29006
# STROKE          29006
# CHECKUP         29006
# CHD             29006
# CHOLSCREEN      29006
# MHLTH           29006
# CANCER          29006
# PHLTH           29006
# CASTHMA         29006
# BPMED           29006
# SLEEP           29006
# BPHIGH          29006
# CSMOKING        29006
# ARTHRITIS       29006
# KIDNEY          29006
# LPA             29006
# DENTAL          29006
# HIGHCHOL        29006
# OBESITY         29006
# ACCESS2         28973
# PAPTEST         28912
# COLON_SCREEN    28847
# MAMMOUSE        28727
# TEETHLOST       28601
# COREM           28464
# COREW           28453
# Name: MeasureId, dtype: int64

# %%
sleepy_df = df[df['MeasureId']=='SLEEP'].copy()

# %%
sleepy_df.head()
# Out:
#      Year StateAbbr StateDesc CityName GeographicLevel DataSource  \
# 6    2016        IL  Illinois  Chicago    Census Tract      BRFSS
# 51   2016        IL  Illinois  Chicago    Census Tract      BRFSS
# 56   2016        IL  Illinois  Chicago    Census Tract      BRFSS
# 58   2016        IL  Illinois  Chicago    Census Tract      BRFSS
# 103  2016        IL  Illinois  Chicago    Census Tract      BRFSS
#
#                 Category             UniqueID  \
# 6    Unhealthy Behaviors  1714000-17031840400
# 51   Unhealthy Behaviors  1714000-17031170800
# 56   Unhealthy Behaviors  1714000-17031160300
# 58   Unhealthy Behaviors  1714000-17031834500
# 103  Unhealthy Behaviors  1714000-17031650200
#
#                                                Measure Data_Value_Unit  ...  \
# 6    Sleeping less than 7 hours among adults aged >...               %  ...
# 51   Sleeping less than 7 hours among adults aged >...               %  ...
# ...

# %%
sleepy_df.columns
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'CityName', 'GeographicLevel',
#        'DataSource', 'Category', 'UniqueID', 'Measure', 'Data_Value_Unit',
#        'DataValueTypeID', 'Data_Value_Type', 'Data_Value',
#        'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'PopulationCount',
#        'GeoLocation', 'CategoryID', 'MeasureId', 'CityFIPS', 'TractFIPS',
#        'Short_Question_Text'],
#       dtype='object')

# %%
sleepy_df['Data_Value'].value_counts()
# Out:
# 36.0    220
# 34.5    215
# 36.8    213
# 34.7    212
# 35.9    210
#        ...
# 22.1      1
# 20.7      1
# 55.1      1
# 20.9      1
# 21.6      1
# Name: Data_Value, Length: 341, dtype: int64

# %%
round(sleepy_df['PopulationCount'] * (sleepy_df['Data_Value'] * .01), 0) #preview
# Out:
# 6         1214.0
# 51        1213.0
# 56        1272.0
# 58         668.0
# 103       2533.0
#            ...
# 809934    1971.0
# 809991    1139.0
# 810031     773.0
# 810056    2387.0
# 810090    1855.0
# Length: 29006, dtype: float64

# %%
sleepy_df['percent_of_pop'] = round(sleepy_df['PopulationCount'] * (sleepy_df['Data_Value'] * .01), 0) #convert to percentage

# %%
sleepy_df.groupby('CityName')['PopulationCount'].sum() #preview
# Out:
# CityName
# Abilene         351189
# Akron           597330
# Alameda         221436
# Albany          525870
# Albuquerque    1637556
#                 ...
# Wyoming         216375
# Yakima          273201
# Yonkers         587928
# Youngstown      200946
# Yuma            279192
# Name: PopulationCount, Length: 474, dtype: int64

# %%
tot_pop_dict = dict(sleepy_df.groupby('CityName')['PopulationCount'].sum())
sleepy_df['tot_city_pop'] = sleepy_df['CityName'].map(tot_pop_dict)

# %%
#preview
sleepy_df[['CityName','percent_of_pop', 'tot_city_pop']]
# Out:
#        CityName  percent_of_pop  tot_city_pop
# 6       Chicago          1214.0     8086794.0
# 51      Chicago          1213.0     8086794.0
# 56      Chicago          1272.0     8086794.0
# 58      Chicago           668.0     8086794.0
# 103     Chicago          2533.0     8086794.0
# ...         ...             ...           ...
# 809934  El Paso          1971.0     1947363.0
# 809991   Dallas          1139.0     3593448.0
# 810031   Dallas           773.0     3593448.0
# 810056  El Paso          2387.0     1947363.0
# 810090   Denton          1855.0      340149.0
#
# [29006 rows x 3 columns]

# %%
perc_pop_dict = dict(sleepy_df.groupby('CityName')['percent_of_pop'].sum())
sleepy_df['perc_city_pop'] = sleepy_df['CityName'].map(perc_pop_dict)

# %%
#preview
sleepy_df[['CityName','percent_of_pop', 'tot_city_pop', 'perc_city_pop']]
# Out:
#        CityName  percent_of_pop  tot_city_pop  perc_city_pop
# 6       Chicago          1214.0     8086794.0      2917566.0
# 51      Chicago          1213.0     8086794.0      2917566.0
# 56      Chicago          1272.0     8086794.0      2917566.0
# 58      Chicago           668.0     8086794.0      2917566.0
# 103     Chicago          2533.0     8086794.0      2917566.0
# ...         ...             ...           ...            ...
# 809934  El Paso          1971.0     1947363.0       716753.0
# 809991   Dallas          1139.0     3593448.0      1245836.0
# 810031   Dallas           773.0     3593448.0      1245836.0
# 810056  El Paso          2387.0     1947363.0       716753.0
# 810090   Denton          1855.0      340149.0       105806.0
#
# [29006 rows x 4 columns]

# %%
#total number of people in the city divided by total city population = full city percentage
sleepy_df['tot_city_percent'] = round(sleepy_df['perc_city_pop'] / sleepy_df['tot_city_pop'],2)

# %%
#preview
sleepy_df[['CityName','percent_of_pop', 'tot_city_pop', 'perc_city_pop', 'tot_city_percent']]
# Out:
#        CityName  percent_of_pop  tot_city_pop  perc_city_pop  tot_city_percent
# 6       Chicago          1214.0     8086794.0      2917566.0              0.36
# 51      Chicago          1213.0     8086794.0      2917566.0              0.36
# 56      Chicago          1272.0     8086794.0      2917566.0              0.36
# 58      Chicago           668.0     8086794.0      2917566.0              0.36
# 103     Chicago          2533.0     8086794.0      2917566.0              0.36
# ...         ...             ...           ...            ...               ...
# 809934  El Paso          1971.0     1947363.0       716753.0              0.37
# 809991   Dallas          1139.0     3593448.0      1245836.0              0.35
# 810031   Dallas           773.0     3593448.0      1245836.0              0.35
# 810056  El Paso          2387.0     1947363.0       716753.0              0.37
# 810090   Denton          1855.0      340149.0       105806.0              0.31
#
# ...

# %%
sleepy_df.shape
# Out:
# (29006, 28)

# %%
sleepy_df.drop_duplicates('CityName', inplace = True) #we only need one entry for each city now

# %%
sleepy_df.shape
# Out:
# (475, 28)

# %%
sleepy_df.columns
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'CityName', 'GeographicLevel',
#        'DataSource', 'Category', 'UniqueID', 'Measure', 'Data_Value_Unit',
#        'DataValueTypeID', 'Data_Value_Type', 'Data_Value',
#        'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'PopulationCount',
#        'GeoLocation', 'CategoryID', 'MeasureId', 'CityFIPS', 'TractFIPS',
#        'Short_Question_Text', 'percent_of_pop', 'tot_city_pop',
#        'perc_city_pop', 'tot_city_percent'],
#       dtype='object')

# %%
sleepy_final = sleepy_df[['Year', 'StateAbbr', 'StateDesc', 'CityName', 'Category', 'CategoryID',
                         'Short_Question_Text', 'tot_city_pop', 'perc_city_pop',
                         'tot_city_percent']].copy()

# %%
sleepy_final.reset_index(inplace=True)

# %%
sleepy_final.drop('index', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-31f8126f11ec> in <module>
# ----> 1 sleepy_final.drop('index', inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...
